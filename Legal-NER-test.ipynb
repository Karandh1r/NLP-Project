# %%
# !nvidia-smi
# Out:
# Tue Dec 13 06:06:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1B.0 Off |                    0 |
# | N/A   28C    P8    14W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla T4            On   | 00000000:00:1C.0 Off |                    0 |
# | N/A   29C    P8    14W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla T4            On   | 00000000:00:1D.0 Off |                    0 |
# | N/A   29C    P8    13W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   29C    P8    14W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -U pip setuptools wheel
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (22.0.4)
# Collecting pip
#   Downloading pip-22.3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 39.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (60.10.0)
# Collecting setuptools
#   Using cached setuptools-65.6.3-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (0.37.1)
# Collecting wheel
#   Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.1
#     Uninstalling wheel-0.37.1:
#       Successfully uninstalled wheel-0.37.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 60.10.0
#     Uninstalling setuptools-60.10.0:
#       Successfully uninstalled setuptools-60.10.0
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# Successfully installed pip-22.3.1 setuptools-65.6.3 wheel-0.38.4

# %%
# !pip install spacy[transformers,cuda110]
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting spacy[cuda110,transformers]
#   Using cached spacy-3.4.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.9-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (21.3)
# Collecting spacy-legacy<3.1.0,>=3.0.10
#   Using cached spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (4.63.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.10.1-py3-none-any.whl (48 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (490 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (806 kB)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (4.1.1)
# Collecting wasabi<1.1.0,>=0.9.1
#   Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (1.21.5)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.8-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (126 kB)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (3.0.3)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (2.27.1)
# Collecting typer<0.8.0,>=0.3.0
#   Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (65.6.3)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Using cached pydantic-1.10.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
# Collecting cupy-cuda110<12.0.0,>=5.0.0b4
#   Using cached cupy_cuda110-11.4.0-cp37-cp37m-manylinux1_x86_64.whl (79.0 MB)
# Collecting spacy-transformers<1.2.0,>=1.1.2
#   Using cached spacy_transformers-1.1.8-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy[cuda110,transformers]) (3.7.0)
# Collecting fastrlock>=0.5
#   Using cached fastrlock-0.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_24_x86_64.whl (46 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from packaging>=20.0->spacy[cuda110,transformers]) (3.0.7)
# Collecting smart-open<7.0.0,>=5.2.1
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (2.0.12)
# Collecting torch>=1.6.0
#   Using cached torch-1.13.0-cp37-cp37m-manylinux1_x86_64.whl (890.2 MB)
# Requirement already satisfied: transformers<4.22.0,>=3.4.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (4.17.0)
# Collecting spacy-alignments<1.0.0,>=0.7.2
#   Using cached spacy_alignments-0.8.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.0.3-py3-none-any.whl (32 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.9-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from typer<0.8.0,>=0.3.0->spacy[cuda110,transformers]) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from jinja2->spacy[cuda110,transformers]) (2.1.1)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.8.0,>=0.3.0->spacy[cuda110,transformers]) (4.11.3)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.38.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (2022.3.15)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.0.49)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (5.4.1)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.11.6)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (3.6.0)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (1.1.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (1.16.0)
# Installing collected packages: wasabi, fastrlock, cymem, spacy-loggers, spacy-legacy, spacy-alignments, smart-open, pydantic, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, murmurhash, langcodes, cupy-cuda110, catalogue, blis, srsly, preshed, nvidia-cudnn-cu11, typer, torch, confection, thinc, pathy, spacy, spacy-transformers
#   Attempting uninstall: torch
#     Found existing installation: torch 1.5.1
#     Uninstalling torch-1.5.1:
#       Successfully uninstalled torch-1.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.6.1 requires torch==1.5.1, but you have torch 1.13.0 which is incompatible.
# torcheia 1.0.0 requires torch==1.5.1, but you have torch 1.13.0 which is incompatible.
# Successfully installed blis-0.7.9 catalogue-2.0.8 confection-0.0.3 cupy-cuda110-11.4.0 cymem-2.0.7 fastrlock-0.8.1 langcodes-3.3.0 murmurhash-1.0.9 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.2 smart-open-6.3.0 spacy-3.4.3 spacy-alignments-0.8.6 spacy-legacy-3.0.10 spacy-loggers-1.0.4 spacy-transformers-1.1.8 srsly-2.4.5 thinc-8.1.5 torch-1.13.0 typer-0.7.0 wasabi-0.10.1

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 25.8 MB/s eta 0:00:0000:0100:01
# Collecting spacy<3.3.0,>=3.2.0
#   Downloading spacy-3.2.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 28.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.27.1)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.17-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.6/660.6 kB 6.8 MB/s eta 0:00:0000:01
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.8)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 43.6 MB/s eta 0:00:0000:0100:01
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.5)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (65.6.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.9)
# Requirement already satisfied: click<8.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.10)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.4)
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: pathy>=0.3.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.63.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.21.5)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.0)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from click<8.1.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (6.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.1.1)
# Installing collected packages: typing-extensions, pydantic, typer, thinc, spacy, en-core-web-sm
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.1.1
#     Uninstalling typing_extensions-4.1.1:
#       Successfully uninstalled typing_extensions-4.1.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.5
#     Uninstalling thinc-8.1.5:
#       Successfully uninstalled thinc-8.1.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.3
#     Uninstalling spacy-3.4.3:
#       Successfully uninstalled spacy-3.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy-transformers 1.1.8 requires spacy<4.0.0,>=3.4.0, but you have spacy 3.2.4 which is incompatible.
# Successfully installed en-core-web-sm-3.2.0 pydantic-1.8.2 spacy-3.2.4 thinc-8.0.17 typer-0.4.2 typing-extensions-3.10.0.2

# %%
# !pip install https://huggingface.co/opennyaiorg/en_legal_ner_trf/resolve/main/en_legal_ner_trf-any-py3-none-any.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting en-legal-ner-trf==any
#   Downloading https://huggingface.co/opennyaiorg/en_legal_ner_trf/resolve/main/en_legal_ner_trf-any-py3-none-any.whl (446.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.7/446.7 MB 1.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from en-legal-ner-trf==any) (1.1.8)
# Requirement already satisfied: spacy<3.3.0,>=3.2.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from en-legal-ner-trf==any) (3.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (1.0.4)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (0.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (1.21.5)
# Requirement already satisfied: click<8.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (8.0.4)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.0.3)
# Requirement already satisfied: pathy>=0.3.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (4.63.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (1.8.2)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (65.6.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.0.10)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (0.7.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (2.4.5)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.10.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (2.27.1)
# Requirement already satisfied: torch>=1.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (1.13.0)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (0.8.6)
# Collecting spacy-transformers<1.2.0,>=1.1.4
#   Downloading spacy_transformers-1.1.7-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: transformers<4.21.0,>=3.4.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (4.17.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.7.0)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from click<8.1.0->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (4.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (6.3.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (3.3)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.6.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.6.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.6.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.6.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (8.5.0.96)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (0.38.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (0.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (2022.3.15)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (3.6.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (0.11.6)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (0.0.49)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (5.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from jinja2->spacy<3.3.0,>=3.2.2->en-legal-ner-trf==any) (2.1.1)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (1.1.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.4->en-legal-ner-trf==any) (1.16.0)
# Installing collected packages: spacy-transformers, en-legal-ner-trf
#   Attempting uninstall: spacy-transformers
#     Found existing installation: spacy-transformers 1.1.8
#     Uninstalling spacy-transformers-1.1.8:
#       Successfully uninstalled spacy-transformers-1.1.8
# Successfully installed en-legal-ner-trf-3.2.0 spacy-transformers-1.1.7

# %%
# !git clone https://github.com/Legal-NLP-EkStep/legal_NER.git
# Out:
# fatal: destination path 'legal_NER' already exists and is not an empty directory.

# %%
cd legal_NER
# Out:
# /home/ec2-user/SageMaker/legal_NER

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.7.1+cu110
#   Downloading https://download.pytorch.org/whl/cu110/torch-1.7.1%2Bcu110-cp37-cp37m-linux_x86_64.whl (1156.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 GB 966.6 kB/s eta 0:00:0000:0100:01
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /torchvision/
# Collecting torchvision==0.8.2+cu110
#   Downloading https://download.pytorch.org/whl/cu110/torchvision-0.8.2%2Bcu110-cp37-cp37m-linux_x86_64.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 27.8 MB/s eta 0:00:0000:0100:01
# Collecting torchaudio===0.7.2
#   Downloading torchaudio-0.7.2-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 72.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch==1.7.1+cu110) (3.10.0.2)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch==1.7.1+cu110) (1.21.5)
# Requirement already satisfied: pillow>=4.1.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torchvision==0.8.2+cu110) (9.0.1)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0
#     Uninstalling torch-1.13.0:
#       Successfully uninstalled torch-1.13.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.6.1
#     Uninstalling torchvision-0.6.1:
#       Successfully uninstalled torchvision-0.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torcheia 1.0.0 requires torch==1.5.1, but you have torch 1.7.1+cu110 which is incompatible.
# Successfully installed torch-1.7.1+cu110 torchaudio-0.7.2 torchvision-0.8.2+cu110

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting nltk
#   Downloading nltk-3.8-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nltk) (4.63.0)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from click->nltk) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.10.0.2)
# Installing collected packages: nltk
# Successfully installed nltk-3.8

# %%
# !pip install spacy[transformers,cuda110]
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: spacy[cuda110,transformers] in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (3.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (2.4.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (0.7.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (2.0.8)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (3.10.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (1.0.9)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (3.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (0.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (4.63.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (3.0.10)
# Requirement already satisfied: pathy>=0.3.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (1.0.4)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (21.3)
# Requirement already satisfied: click<8.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (8.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (1.21.5)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (65.6.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (8.0.17)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (2.27.1)
# Collecting cupy-cuda110<11.0.0,>=5.0.0b4
#   Downloading cupy_cuda110-10.6.0-cp37-cp37m-manylinux1_x86_64.whl (77.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 MB 28.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy[cuda110,transformers]) (1.1.7)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy[cuda110,transformers]) (3.7.0)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from click<8.1.0->spacy[cuda110,transformers]) (4.11.3)
# Requirement already satisfied: fastrlock>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from cupy-cuda110<11.0.0,>=5.0.0b4->spacy[cuda110,transformers]) (0.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from packaging>=20.0->spacy[cuda110,transformers]) (3.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pathy>=0.3.5->spacy[cuda110,transformers]) (6.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,transformers]) (2.0.12)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.8.6)
# Requirement already satisfied: transformers<4.21.0,>=3.4.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (4.17.0)
# Requirement already satisfied: torch>=1.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (1.7.1+cu110)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from jinja2->spacy[cuda110,transformers]) (2.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.4.0)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.0.49)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (3.6.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (0.11.6)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (2022.3.15)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (1.16.0)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[cuda110,transformers]) (1.1.0)
# Installing collected packages: cupy-cuda110
#   Attempting uninstall: cupy-cuda110
#     Found existing installation: cupy-cuda110 11.4.0
#     Uninstalling cupy-cuda110-11.4.0:
#       Successfully uninstalled cupy-cuda110-11.4.0
# Successfully installed cupy-cuda110-10.6.0

# %%
import spacy
print(spacy.require_gpu())
# Out:
# True

# %%
import spacy
from data_preparation import get_text_from_indiankanoon_url
from spacy import displacy
from legal_ner import extract_entities_from_judgment_text
import urllib

legal_nlp=spacy.load('en_legal_ner_trf')
judgment_text = urllib.request.urlopen('https://raw.githubusercontent.com/OpenNyAI/Opennyai/master/samples/sample_judgment1.txt').read().decode()

preamble_spiltting_nlp = spacy.load('en_core_web_sm')
run_type='sent' ###  trade off between accuracy and runtime
do_postprocess=True 
combined_doc = extract_entities_from_judgment_text(judgment_text,legal_nlp,preamble_spiltting_nlp,run_type,do_postprocess)
# Out:
# Seperating Preamble took 19.115887880325317
# Creating doc for jdgement  took 1.7207555770874023
# 99
# Creating doc for preamble  took 0.022578954696655273
# Combining took 0.0064046382904052734
# /home/ec2-user/SageMaker/legal_NER/data_preparation.py:261: UserWarning: [W101] Skipping Doc custom extension 'trf_data' while merging docs.
#   combined_docs=spacy.tokens.Doc.from_docs(docs)
# /home/ec2-user/SageMaker/legal_NER/legal_ner.py:39: UserWarning: [W101] Skipping Doc custom extension 'trf_data' while merging docs.
#   combined_doc = spacy.tokens.Doc.from_docs([doc_preamble, doc_judgment])

# %%
extracted_ent_labels = list(set([i.label_ for i in combined_doc.ents]))
colors = {'COURT': "#bbabf2", 'PETITIONER': "#f570ea", "RESPONDENT": "#cdee81", 'JUDGE': "#fdd8a5",
          "LAWYER": "#f9d380", 'WITNESS': "violet", "STATUTE": "#faea99", "PROVISION": "yellow",
          'CASE_NUMBER': "#fbb1cf", "PRECEDENT": "#fad6d6", 'DATE': "#b1ecf7", 'OTHER_PERSON': "#b0f6a2",
          'ORG':'#a57db5','GPE':'#7fdbd4'}
options = {"ents": extracted_ent_labels, "colors": colors}
displacy.serve(combined_doc, style='ent',port=8080,options=options)
# Out:
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/spacy/displacy/__init__.py:98: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">                                                   Reportable</br></br>            In The
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Supreme Court Of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
# </br>             Civil Appellate Jurisdiction</br></br>             Civil Appeal No. 8990 Of 2017</br></br>
# <mark class="entity" style="background: #f570ea; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Executive Engineer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PETITIONER</span>
# </mark>
#  (R And B)</br>And Others                                    ...Appellant(S)</br></br>                           Versus</br>
# <mark class="entity" style="background: #cdee81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gokul Chandra Kanungo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">RESPONDENT</span>
# </mark>
#  (Dead)</br>Thr. His Lrs.                                ...Respondent(S)</br></br>                         Judgment</br>
# <mark class="entity" style="background: #fdd8a5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     B.R. GAVAI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JUDGE</span>
# </mark>
# , J.</br></br>1. The appellants have challenged the judgment dated
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18th April 2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  passed by the learned Single Judge of the
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     High Court of Orissa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
#  in
# <mark class="entity" style="background: #fbb1cf; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arbitration Appeal No. 25 of 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASE_NUMBER</span>
# </mark>
# , thereby dismissing the appeal filed by the appellants. </br></br>2. The facts in brief giving rise to the present appeal are as under:</br></br>The respondent was awarded the contract for construction of 3 kilometers missing link on NH­6 from
# <mark class="entity" style="background: #7fdbd4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanjipani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #7fdbd4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kuntala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16th December 1971
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The work was to be completed within one year that is before
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 th December 1972
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The contract amount was Rs.4,59,330/­. However, the work could not be completed by the stipulated date and it was completed only on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30th August 1977
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , by which date, the respondent was already paid an amount of Rs.3,36,465/­.</br></br>3. The respondent, on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25th July 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , issued a notice to the appellant regarding his claim. The said notice was replied to by the appellant on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 th August 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  stating therein that, as against the claim of Rs.3,34,744/­, the respondent had been paid an amount of Rs.3,36,465/­. The respondent thereafter filed a suit being O.S.
# <mark class="entity" style="background: #fbb1cf; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     No. 206 of 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASE_NUMBER</span>
# </mark>
#  before the
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Court of Civil Judge (Senior Division), Bhubaneswar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
#  (hereinafter referred to as the “trial court”) under
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Section 20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROVISION</span>
# </mark>
#  of the
# <mark class="entity" style="background: #faea99; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arbitration Act, 1940
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUTE</span>
# </mark>
#  (for short, “the 1940 Act”) seeking reference of the dispute to arbitration. By order of the trial court dated
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14th February 1990
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# <
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:8080 ...
#
# Shutting down server on port 8080.

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python -m spacy train training/config.cfg --output ./output --paths.train training/Combined_Data_Judgement_Preamble_spacy_format/train.spacy --paths.dev training/Combined_Data_Judgement_Preamble_spacy_format/dev.spacy --gpu-id 0
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ℹ Saving to output directory: output
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# =========================== Initializing pipeline ===========================
# [2022-12-13 06:10:53,887] [INFO] Set up nlp object from config
# [2022-12-13 06:10:53,896] [INFO] Pipeline: ['transformer', 'ner']
# [2022-12-13 06:10:53,899] [INFO] Created vocabulary
# [2022-12-13 06:10:53,900] [INFO] Finished initializing nlp object
# Downloading: 100%|██████████████████████████████| 481/481 [00:00<00:00, 819kB/s]
# Downloading: 100%|███████████████████████████| 878k/878k [00:00<00:00, 50.0MB/s]
# Downloading: 100%|███████████████████████████| 446k/446k [00:00<00:00, 45.6MB/s]
# Downloading: 100%|█████████████████████████| 1.29M/1.29M [00:00<00:00, 49.4MB/s]
# Downloading: 100%|███████████████████████████| 478M/478M [00:05<00:00, 85.6MB/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [2022-12-13 06:11:23,577] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
# Token indices sequence length is longer than the specified maximum sequence length for this model (514 > 512). Running this sequence through the model will result in indexing errors
#   0       0       27304.96    708.92    0.02    0.02    0.03    0.00
